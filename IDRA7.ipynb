# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Day7_Student_Dataset.csv")

# %%
firstrows = df.head()
lastrows = df.tail()
samples = df.sample(5)

print("first 5 rows :")
print(firstrows)

print("\nlast 5 rows :")
print(lastrows)

print("\n random 5 samples :")
print(samples)
# Out:
# first 5 rows :
#    Student_ID          Name  Age            Course  Marks  \
# 0        1001  Aarav Sharma   19      Data Science   87.0
# 1        1002     Zoya Khan   20                AI   92.0
# 2        1003   Rohan Mehta   18  Computer Science   76.0
# 3        1004  Ananya Singh   21      Data Science   81.0
# 4        1005     Kabir Ali   19                AI   69.0
#
#    Attendance_Percentage      City
# 0                   91.0  Srinagar
# 1                   95.0     Delhi
# 2                   82.0    Mumbai
# 3                   88.0  Srinagar
# 4                   76.0   Lucknow
#
# last 5 rows :
#     Student_ID          Name  Age            Course  Marks  \
# 20        1021    Aman Kumar   18  Computer Science   74.0
# 21        1022    Alina Shah   19      Data Science   96.0
# 22        1023   Nikhil Sood   22                AI   78.0
# 23        1024   Maryam Khan   20  Computer Science   85.0
# 24        1025  Reyansh Jain   21      Data Science   80.0
#
#     Attendance_Percentage       City
# 20                   78.0      Delhi
# 21                   98.0   Srinagar
# 22                   83.0       Pune
# 23                   88.0  Hyderabad
# 24                   84.0    Kolkata
#
#  random 5 samples :
#     Student_ID          Name  Age            Course  Marks  \
# 5         1006  Ishita Gupta   20  Computer Science   88.0
# 12        1013     Rahul Das   23      Data Science   72.0
# 13        1014    Sana Malik   18                AI   89.0
# 3         1004  Ananya Singh   21      Data Science   81.0
# 1         1002     Zoya Khan   20                AI   92.0
#
#     Attendance_Percentage       City
# 5                    93.0  Bengaluru
# 12                   81.0    Kolkata
# 13                   92.0        NaN
# 3                    88.0   Srinagar
# 1                    95.0      Delhi

# %%
shape = df.shape
columns = df.columns
index = df.index
datatypes = df.dtypes


print("shape of the dataset : ",shape)
print("columns of the dataset : ",columns.tolist())
print("index of the dataset : ",index)
print("datatypes of the dataset : \n",datatypes)
# Out:
# shape of the dataset :  (25, 7)
# columns of the dataset :  ['Student_ID', 'Name', 'Age', 'Course', 'Marks', 'Attendance_Percentage', 'City']
# index of the dataset :  RangeIndex(start=0, stop=25, step=1)
# datatypes of the dataset :
#  Student_ID                 int64
# Name                      object
# Age                        int64
# Course                    object
# Marks                    float64
# Attendance_Percentage    float64
# City                      object
# dtype: object

# %% [markdown]
# ## decriptive statistics

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             25 non-null     int64
#  1   Name                   25 non-null     object
#  2   Age                    25 non-null     int64
#  3   Course                 25 non-null     object
#  4   Marks                  24 non-null     float64
#  5   Attendance_Percentage  24 non-null     float64
#  6   City                   24 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.5+ KB
#         Student_ID        Age      Marks  Attendance_Percentage
# count    25.000000  25.000000  24.000000              24.000000
# mean   1013.000000  20.000000  82.250000              87.083333
# std       7.359801   1.414214   8.689074               7.252686
# min    1001.000000  18.000000  68.000000              72.000000
# 25%    1007.000000  19.000000  75.500000              82.750000
# 50%    1013.000000  20.000000  82.500000              88.000000
# 75%    1019.000000  21.000000  89.250000              92.250000
# max    1025.000000  23.000000  96.000000              98.000000

# %%
for column in df.columns:
    print(f"\n{column}:")
    print("Unique values:", df[column].nunique())
# Out:
# Student_ID:
# Unique values: 25
#
# Name:
# Unique values: 25
#
# Age:
# Unique values: 6
#
# Course:
# Unique values: 3
#
# Marks:
# Unique values: 24
#
# Attendance_Percentage:
# Unique values: 22
#
# City:
# Unique values: 13

# %%
print("number of rows : ", shape[0])
print("number of columns: ", shape[1])

print("Missing values in each column:")
print(df.isnull().sum())

print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# number of rows :  25
# number of columns:  7
# Missing values in each column:
# Student_ID               0
# Name                     0
# Age                      0
# Course                   0
# Marks                    1
# Attendance_Percentage    1
# City                     1
# dtype: int64
# Number of duplicate rows: 0

# %%
numerical_features = df.select_dtypes(include=np.number).columns.tolist()
categorical_features = df.select_dtypes(exclude=np.number).columns.tolist()

print("Numerical features:")
print(numerical_features)

print("\nCategorical features:")
print(categorical_features)
# Out:
# Numerical features:
# ['Student_ID', 'Age', 'Marks', 'Attendance_Percentage']
#
# Categorical features:
# ['Name', 'Course', 'City']
